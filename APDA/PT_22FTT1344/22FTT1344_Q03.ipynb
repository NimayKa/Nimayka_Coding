# %% [markdown]
# Question 3 A )

# %%
import pandas as pd
import matplotlib.pylab as plt

df = pd.read_csv('medals2021.csv')

# %% [markdown]
# Question 3 B )

# %%
df.drop_duplicates(subset=['Rank'],inplace=True)

# %% [markdown]
# Question 3 C )

# %%
df.drop_duplicates(subset=['Continent','Team'],keep= 'last', inplace=True)

# %%
df.head()
# Out:
#    Rank                        Team  Gold Medal  Silver Medal  Bronze Medal  \
# 0     1    United States of America          39            41            33
# 1     2  People's Republic of China          38            32            18
# 2     3                       Japan          27            14            17
# 3     4               Great Britain          22            21            22
# 4     5                         ROC          20            28            23
#
#    Total  Rank by Total NOCCode      Continent
# 0    113              1     USA  North America
# 1     88              2     CHN           Asia
# 2     58              5     JPN           Asia
# 3     65              4     GBR         Europe
# 4     71              3     ROC    Europe/Asia

# %% [markdown]
# Question 3 D )

# %%
df = df[['Rank','Team','Gold Medal','Silver Medal','Bronze Medal']]
df_top10 = df[df['Rank'] <= 10]

medal = df_top10[['Gold Medal','Silver Medal','Bronze Medal']]
df_top10.plot.bar(x=('Team'), color=['Green','Gold','Silver','Brown'], stacked = True)
plt.xlabel('Team')
# Out:
# Text(0.5, 0, 'Team')
