# %%
import pandas as pd

df = pd.read_csv("telco-customer-churn.csv")
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors='coerce')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df_dsl=df.loc[(df['InternetService'] == 'DSL')]
df_dsl.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 7  6713-OKOMC  Female              0      No         No      10           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 7  No phone service             DSL            Yes  ...               No
#
# ...

# %%
df_dsl_isn=df.loc[(df['PhoneService'] == 'Yes')&(df['InternetService'] == 'No') ]
df_dsl_isn.head(5)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 11  7469-LKBCI    Male              0      No         No      16          Yes
# 16  8191-XWSZG  Female              0      No         No      52          Yes
# 21  1680-VDCWW    Male              0     Yes         No      12          Yes
# 22  1066-JKSGK    Male              0      No         No       1          Yes
# 33  7310-EGVHZ    Male              0      No         No       1          Yes
#
#    MultipleLines InternetService       OnlineSecurity  ...  \
# 11            No              No  No internet service  ...
# 16            No              No  No internet service  ...
# 21            No              No  No internet service  ...
# 22            No              No  No internet service  ...
# 33            No              No  No internet service  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 11  No internet service  No internet service  No internet service
# ...

# %%
df_fgender_py_isn=df.loc[(df['gender'] == 'Female')&(df['PhoneService'] == 'Yes')&(df['InternetService'] == 'No') ]
df_fgender_py_isn.head(5)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 16  8191-XWSZG  Female              0      No         No      52          Yes
# 42  9867-JCZSP  Female              0     Yes        Yes      17          Yes
# 58  3957-SQXML  Female              0     Yes        Yes      34          Yes
# 68  3170-NMYVV  Female              0     Yes        Yes      50          Yes
# 71  0731-EBJQB  Female              0     Yes        Yes      52          Yes
#
#    MultipleLines InternetService       OnlineSecurity  ...  \
# 16            No              No  No internet service  ...
# 42            No              No  No internet service  ...
# 58           Yes              No  No internet service  ...
# 68            No              No  No internet service  ...
# 71            No              No  No internet service  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 16  No internet service  No internet service  No internet service
# ...

# %%
 df.loc[df['customerID'].str.contains('T')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 9     6388-TABGU    Male              0      No        Yes      62
# 12    8091-TTVAX    Male              0     Yes         No      58
# 17    9959-WOFKT    Male              0      No        Yes      71
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# ...          ...     ...            ...     ...        ...     ...
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7022  7203-OYKCT    Male              0      No         No      72
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 4             Yes                No     Fiber optic             No  ...
# ...

# %%
df.iloc[50:61,18:]
# Out:
#     MonthlyCharges  TotalCharges Churn  count  Gender
# 50           90.25       3838.75    No      1       1
# 51           99.10       1426.40   Yes      1       1
# 52           69.50       1752.65    No      1       1
# 53           80.65        633.30   Yes      1       1
# 54           74.85       4456.35    No      1       1
# 55           95.45       1752.55   Yes      1       1
# 56           99.65       6311.20    No      1       1
# 57          108.45       7076.35    No      1       1
# 58           24.95        894.30    No      1       1
# 59          107.50       7853.70    No      1       1
# 60          100.50       4707.10    No      1       1

# %%
df.loc[df['PaymentMethod'] == 'Electronic check', 'PaymentMethod'] ='eCheck'
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df['count'] = 1 
df.groupby(["PaymentMethod"]).count()['count']
# Out:
# PaymentMethod
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Mailed check                 1612
# eCheck                       2365
# Name: count, dtype: int64

# %%
df.groupby(["PaymentMethod"]).mean(numeric_only=True)
# Out:
#                            SeniorCitizen     tenure  MonthlyCharges  \
# PaymentMethod
# Bank transfer (automatic)       0.150907  43.656736       67.192649
# Credit card (automatic)         0.145204  43.269382       66.512385
# Mailed check                    0.058313  21.830025       43.917060
# eCheck                          0.251163  25.174630       76.255814
#
#                            TotalCharges  count  Gender
# PaymentMethod
# Bank transfer (automatic)   3079.299546    1.0     1.0
# Credit card (automatic)     3071.396022    1.0     1.0
# Mailed check                1054.483915    1.0     1.0
# eCheck                      2090.868182    1.0     1.0

# %%
df.groupby(['gender']).sum(numeric_only=True)
# Out:
#         SeniorCitizen  tenure  MonthlyCharges  TotalCharges  count  Gender
# gender
# Female            568  112469        227432.4     7952354.2   3488    3488
# Male              574  115521        228684.2     8103814.5   3555    3555

# %%
sumcol=df.groupby(['gender']).sum(numeric_only=True)
sumcol['MonthlyCharges']
# Out:
# gender
# Female    227432.4
# Male      228684.2
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby(['gender']).mean(numeric_only=True)['MonthlyCharges']
# Out:
# gender
# Female    65.204243
# Male      64.327482
# Name: MonthlyCharges, dtype: float64
