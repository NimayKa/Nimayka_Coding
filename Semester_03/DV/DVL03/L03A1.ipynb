# %%
import pandas as pd

df = pd.read_csv("pokemon_data.csv")
print (df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[(df['Type 1'] == 'Grass')&(df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[(df['Type 1'] == 'Grass')&(df['Type 2'] == 'Poison')&(df['Attack']<= 50)]
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1  Bulbasaur  Grass  Poison  45      49       49       65       65
# 48    43     Oddish  Grass  Poison  45      50       55       75       65
# 451  406      Budew  Grass  Poison  40      30       35       50       70
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 48      30           1      False
# 451     55           4      False

# %%
df.loc[(df['Legendary'] == True)&(df['Type 1'] == 'Grass')]
# Out:
#        #               Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 550  492  ShayminLand Forme  Grass       NaN  100     100      100      100
# 551  492   ShayminSky Forme  Grass    Flying  100     103       75      120
# 701  640           Virizion  Grass  Fighting   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# 550      100    100           4       True
# 551       75    127           4       True
# 701      129    108           5       True

# %%
new_df = df.loc[(df['Type 1']=='Water')&(df['Type 2']=='Flying')&(df['HP'] >= 60)]
new_df = new_df.reset_index()
new_df
# Out:
#    index    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    140  130  Gyarados  Water  Flying  95     125       79       60      100
# 1    244  226   Mantine  Water  Flying  65      40       70       80      140
# 2    302  279  Pelipper  Water  Flying  60      50      100       85       70
# 3    641  580  Ducklett  Water  Flying  62      44       50       44       50
# 4    642  581    Swanna  Water  Flying  75      87       63       87       63
#
#    Speed  Generation  Legendary
# 0     81           1      False
# 1     70           2      False
# 2     65           3      False
# 3     55           5      False
# 4     98           5      False

# %%
 df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
df.iloc[4:11,1:6]
# Out:
#                          Name Type 1  Type 2  HP  Attack
# 4                  Charmander   Fire     NaN  39      52
# 5                  Charmeleon   Fire     NaN  58      64
# 6                   Charizard   Fire  Flying  78      84
# 7   CharizardMega Charizard X   Fire  Dragon  78     130
# 8   CharizardMega Charizard Y   Fire  Flying  78     104
# 9                    Squirtle  Water     NaN  44      48
# 10                  Wartortle  Water     NaN  59      63

# %%
df.loc[(df['Name']=='Charmander')&(df['HP'] == 39)&(df['Attack']==52)]
# Out:
#    #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 4  4  Charmander   Fire    NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 4           1      False

# %%
df.loc[df['Type 1'] == 'Grass', 'Type 1'] ='Rumput'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur   Rumput  Poison  45      49       49
# 1      2                Ivysaur   Rumput  Poison  60      62       63
# 2      3               Venusaur   Rumput  Poison  80      82       83
# 3      3  VenusaurMega Venusaur   Rumput  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Attack'] >100,['Generation','Legendary']] ='Too OP'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur   Rumput  Poison  45      49       49
# 1      2                Ivysaur   Rumput  Poison  60      62       63
# 2      3               Venusaur   Rumput  Poison  80      82       83
# 3      3  VenusaurMega Venusaur   Rumput  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary
# 0         65       65     45          1     False
# ...

# %%
df = pd.read_csv('pokemon_data.csv')
df.loc[df['Attack']> 100,['Generation','Legendary']] = ['Gen OP', 'LegenOP']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary
# 0         65       65     45          1     False
# ...

# %%
df.groupby(["Type 1"]).mean(numeric_only=True)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...
