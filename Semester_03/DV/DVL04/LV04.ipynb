# %%
import pandas as pd

df = pd.read_csv("Dirty_dataset.csv")

df.head(5)
# Out:
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0
# 1  2                Ivysaur  Grass  Poison  60.0    62.0     63.0     80.0
# 2  3               Venusaur  Grass  Poison  80.0    82.0      NaN    100.0
# 3  4  VenusaurMega Venusaur  Grass  Poison  80.0   100.0      NaN    122.0
# 4  5             Charmander   Fire     NaN  39.0    52.0     43.0     60.0
#
#    Sp. Def  Speed  Generation  Legendary
# 0     65.0   45.0           1      False
# 1     80.0   60.0           1      False
# 2    100.0   80.0           1      False
# 3    120.0   80.0           1      False
# 4     50.0   65.0           1      False

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# Length: 175, dtype: bool

# %%
df.duplicated(subset=['Name','Type 1'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 170    False
# 171    False
# 172    False
# 173     True
# 174    False
# Length: 175, dtype: bool

# %%
df.Name.duplicated().sum()
# Out:
# 9

# %%
df.loc[df.duplicated(),:]
# Out:
#      #      Name    Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 51  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
# 70  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
#
#     Speed  Generation  Legendary
# 51  110.0           1      False
# 70   95.0           1      False

# %%
df.loc[df.duplicated(keep=False),:]
# Out:
#      #      Name    Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
# 32  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
# 51  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
# 70  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
#
#     Speed  Generation  Legendary
# 20   95.0           1      False
# 32  110.0           1      False
# 51  110.0           1      False
# 70   95.0           1      False

# %%
df.drop_duplicates()
#df.drop_duplicates(inplace=True)  make permenant changes
df.duplicated().sum()
# Out:
#        #                   Name   Type 1    Type 2     HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass    Poison   45.0    49.0     49.0
# 1      2                Ivysaur    Grass    Poison   60.0    62.0     63.0
# 2      3               Venusaur    Grass    Poison   80.0    82.0      NaN
# 3      4  VenusaurMega Venusaur    Grass    Poison   80.0   100.0      NaN
# 4      5             Charmander     Fire       NaN   39.0    52.0     43.0
# ..   ...                    ...      ...       ...    ...     ...      ...
# 170  169              Dragonite   Dragon    Flying   91.0   134.0     95.0
# 171  170                 Mewtwo  Psychic       NaN  106.0   110.0     90.0
# 172  171    MewtwoMega Mewtwo X  Psychic  Fighting  106.0   190.0    100.0
# 173  172    MewtwoMega Mewtwo Y  Psychic       NaN  106.0   150.0     70.0
# 174  173                    Mew  Psychic       NaN  100.0   100.0    100.0
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#df_last= df.drop_duplicates(keep='last') drop all duplicates data, but keep the last one

# %%
df.isnull().sum()
# Out:
# #              0
# Name           0
# Type 1         0
# Type 2        95
# HP             1
# Attack         2
# Defense        6
# Sp. Atk        2
# Sp. Def        7
# Speed          1
# Generation     0
# Legendary      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# 0

# %%
df['Defense'].fillna(90)
df.head(10)
# Out:
#     #                       Name Type 1  Type 2    HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 1   2                    Ivysaur  Grass  Poison  60.0    62.0     63.0
# 2   3                   Venusaur  Grass  Poison  80.0    82.0      NaN
# 3   4      VenusaurMega Venusaur  Grass  Poison  80.0   100.0      NaN
# 4   5                 Charmander   Fire     NaN  39.0    52.0     43.0
# 5   6                 Charmeleon   Fire     NaN  58.0    64.0     58.0
# 6   7                  Charizard   Fire  Flying  78.0    84.0     78.0
# 7   8  CharizardMega Charizard X   Fire  Dragon  78.0     NaN    111.0
# 8   9  CharizardMega Charizard Y   Fire  Flying  78.0     NaN     78.0
# 9  10                   Squirtle  Water     NaN  44.0    48.0     65.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0           1      False
# 1     80.0     80.0   60.0           1      False
# ...

# %%
df['Defense'].fillna(df['Defense'].mean())
df['Defense'].fillna(df['Defense'].median())
df['Defense'].fillna(df['Defense'].mode())
