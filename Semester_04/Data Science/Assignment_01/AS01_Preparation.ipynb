# %%
import pandas as pd
from numpy import nan as NA 

df = pd.read_csv('netflix1.csv')

df.head(10)
# Out:
#   show_id     type                             title             director  \
# 0      s1    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1      s3  TV Show                         Ganglands      Julien Leclercq
# 2      s6  TV Show                     Midnight Mass        Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4      s8    Movie                           Sankofa         Haile Gerima
# 5      s9  TV Show     The Great British Baking Show      Andy Devonshire
# 6     s10    Movie                      The Starling       Theodore Melfi
# 7    s939    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8     s13    Movie                      Je Suis Karl  Christian Schwochow
# 9    s940    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
new_data = {'country': ['United States', 'India', 'United Kingdom', 'Pakistan', 'Not Given', 'Canada', 'Japan', 'South Korea', 'France',
                    'Spain', 'Mexico', 'Egypt', 'Australia', 'Turkey', 'Nigeria', 'Germany', 'China', 'Brazil', 'Taiwan','Austria','Paraguay',
                    'Italy','South Africa','Philippines','Hong Kong','Argentina','New Zealand','Colombia','Belgium','Switzerland','Bulgaria',
                    'Poland','Saudi Arabia', 'Thailand', 'Indonesia','Kuwait', 'Malaysia', 'Vietnam', 'Lebanon', 'Romania', 'Syria',
                    'United Arab Emirates', 'Sweden', 'Mauritius', 'Czech Republic','Cameroon', 'Netherlands', 'Ireland', 'Russia', 'Kenya', 'Chile',
                    'Uruguay', 'Bangladesh', 'Portugal', 'Hungary', 'Norway','Singapore', 'Iceland', 'Serbia', 'Namibia', 'Peru','Mozambique',
                    'Ghana', 'Zimbabwe', 'Israel', 'Finland', 'Denmark', 'Cambodia','Georgia', 'Greece', 'West Germany', 'Iran','Venezuela',
                    'Slovenia', 'Guatemala', 'Jamaica', 'Somalia','Croatia', 'Jordan', 'Luxembourg', 'Senegal', 'Belarus','Puerto Rico', 'Cyprus', 'Ukraine'],
            
        'latitude': [37.0902, 20.5937, 51.5099, 30.3753, NA , 56.1304, 36.2048, 35.9078, 46.6035, 40.4637, 23.6345, 26.8206, -25.2744, 38.9637,
                     9.0820, 51.1657, 35.8617, -14.2350, 23.6978,47.5261,-23.1366,43.1117,-30.8369,12.4061,22.3333,-35.2982,-43.0015,3.2807,
                     50.5272,46.7679,42.5237,52.9623,23.9347,15.4349,-1.6325,29.3418,5.2503,14.4362,34.0806,45.7902,35.0447,
                     23.7058,62.7404,-20.2794,49.6417,5.7670,52.1424,53.1623,62.1874,0.4834,-26.7950,
                     -32.8084, 24.1990,39.6905,47.0243,61.8980,1.2810,64.9922,44.0829,-22.1316,-10.4548,-17.2902,
                     7.8962,-19.0239,30.9813,61.9880,55.4926,12.6535,42.1719,39.4600,51.2409,32.0776,7.0678,
                     46.0426,15.6653,18.1496,2.8049,45.1148,31.3664,49.6074,14.3647,53.1926,18.1876,35.0420,48.9972],
        
        'longitude': [-95.7129, 78.9629, -0.1180, 69.3451, NA , -106.3468, 138.2529, 127.7669, 1.8883, -3.7492, -102.5528, 30.8028, 133.7751, 35.2433,
                      8.6753, 10.4515, 104.1954, -51.9253, 120.9605, 14.1532, -58.5052, 12.2706, 24.3079, 122.8902, 114.1737, -65.1078, 172.7563,
                      -73.5052, 4.7732, 7.8059, 25.0571, 18.7625, 45.4059, 100.7513, 116.0666, 47.4608, 101.9543, 107.9406, 35.8634, 24.8650, 38.3808, 
                      53.9585, 16.3882, 57.4916, 14.8823, 12.4551, 5.6426, -8.1494, 99.0598, 37.9153, -70.3280,
                      -56.0212, 90.2551, -8.5897, 19.5879, 9.4043, 103.8502, -18.6334, 20.7589, 17.2226, -75.4037, 35.5456,
                      -1.2309, 29.8436, 34.8616, 26.2555, 10.0663, 104.8568, 43.5205, 22.5835, 7.1527, 54.2631, -66.1327, 
                      14.6336, -90.3860, -77.3192, 45.1833, 14.8731, 36.7877, 6.1195, -14.4677, 28.0200, -66.6436, 33.2127, 31.3462]}

new_df = pd.DataFrame(new_data)

merged_df = pd.merge(df, new_df, on='country', how='left')

# %%
df['latitude'] = merged_df['latitude']
df['longitude'] = merged_df['longitude']

# %%
df = df.drop(columns=["show_id"])

# %%
df.head(10)
# Out:
#       type                             title             director  \
# 0    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1  TV Show                         Ganglands      Julien Leclercq
# 2  TV Show                     Midnight Mass        Mike Flanagan
# 3    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4    Movie                           Sankofa         Haile Gerima
# 5  TV Show     The Great British Baking Show      Andy Devonshire
# 6    Movie                      The Starling       Theodore Melfi
# 7    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8    Movie                      Je Suis Karl  Christian Schwochow
# 9    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# 1          France  9/24/2021          2021  TV-MA   1 Season
# ...

# %%
df.isna().sum()
# Out:
# type              0
# title             0
# director          0
# country           0
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# latitude        288
# longitude       288
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# latitude        0
# longitude       0
# dtype: int64

# %%
df.dtypes
# Out:
# type             object
# title            object
# director         object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# latitude        float64
# longitude       float64
# dtype: object

# %%
df.to_csv('netflix.csv', index=False)
