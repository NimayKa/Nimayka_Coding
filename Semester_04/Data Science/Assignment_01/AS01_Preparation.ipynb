# %%
import pandas as pd

df = pd.read_csv('netflix1.csv')

df.sample(10)
# Out:
#      show_id     type                                              title  \
# 1555   s1806    Movie                                    Bending the Arc
# 4959   s6843    Movie                                          Get Smart
# 4134   s5780    Movie  Unchained: The Untold Story of Freestyle Motoc...
# 3294   s4538    Movie                                   The Black Prince
# 4234   s5937    Movie                                  Shrek the Musical
# 4747   s6567    Movie                                        Dark Places
# 4940   s6814    Movie                                       Frozen River
# 1596   s1858    Movie              The Three Deaths of Marisela Escobedo
# 7460   s3242  TV Show                                Nailed It! Holiday!
# 3890   s5441    Movie                                       Shimmer Lake
#
#                         director         country  date_added  release_year  \
# 1555    Kief Davidson, Pedro Kos   United States  10/22/2020          2017
# ...
