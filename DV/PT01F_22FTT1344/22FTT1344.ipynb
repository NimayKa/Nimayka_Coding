# %% [markdown]
# QUESTION 01

# %%
#Question 01a)
import pandas as pd

df = pd.read_csv('PT01_01.csv')

df.head(3)
# Out:
#   Purchase ID      Name Day of purchase  Item 1  Item 2  Item 3
# 0  32-9842871     Jenan        Saturday       4       4       3
# 1  32-7281683       Bel        Thursday       0       3       5
# 2  18-5587912  Jannelle          Sunday       0       2       4

# %%
#Question 01b)
df.describe()
# Out:
#            Item 1      Item 2      Item 3
# count  124.000000  124.000000  124.000000
# mean     2.435484    2.282258    2.532258
# std      1.817896    1.755644    1.564003
# min      0.000000    0.000000    0.000000
# 25%      1.000000    1.000000    1.000000
# 50%      2.000000    2.000000    3.000000
# 75%      4.000000    4.000000    4.000000
# max      5.000000    5.000000    5.000000

# %%
#Question 01c)
df.mean(numeric_only=True)
# Out:
# Item 1    2.435484
# Item 2    2.282258
# Item 3    2.532258
# dtype: float64

# %%
#Question 01d)
df.columns
# Out:
# Index(['Purchase ID', 'Name', 'Day of purchase', 'Item 1', 'Item 2', 'Item 3'], dtype='object')

# %%
#question 1e)
df['Day of purchase'].value_counts()
# Out:
# Day of purchase
# Thursday     26
# Wednesday    20
# Sunday       19
# Tuesday      19
# Monday       16
# Saturday     15
# Friday        9
# Name: count, dtype: int64

# %%
#Question 01f)
df01= df[['Name','Day of purchase','Item 2']]
df01.iloc[3:16]
# Out:
#        Name Day of purchase  Item 2
# 3   Jo-anne        Saturday       3
# 4       Ola        Thursday       0
# 5     Angie        Thursday       2
# 6     Marga       Wednesday       5
# 7    Buckie         Tuesday       3
# 8   Aloisia         Tuesday       4
# 9    Seward       Wednesday       5
# 10   Wileen        Saturday       3
# 11  Kristin          Friday       2
# 12   Rhonda          Monday       4
# 13    Halli          Friday       0
# 14   Vinson        Saturday       4
# 15     Gian        Saturday       0

# %%
#Question 01g)
df.iloc[:10]
# Out:
#   Purchase ID      Name Day of purchase  Item 1  Item 2  Item 3
# 0  32-9842871     Jenan        Saturday       4       4       3
# 1  32-7281683       Bel        Thursday       0       3       5
# 2  18-5587912  Jannelle          Sunday       0       2       4
# 3  76-6713648   Jo-anne        Saturday       0       3       2
# 4  02-7819637       Ola        Thursday       0       0       2
# 5  99-1711438     Angie        Thursday       1       2       2
# 6  62-3103838     Marga       Wednesday       0       5       4
# 7  08-9452186    Buckie         Tuesday       5       3       4
# 8  29-1397295   Aloisia         Tuesday       2       4       0
# 9  31-3981821    Seward       Wednesday       5       5       3

# %% [markdown]
# Question 02

# %%
#Question 02a)
df = pd.read_csv('PT01_01.csv')
df.loc[df['Day of purchase']== 'Thursday']
# Out:
#     Purchase ID        Name Day of purchase  Item 1  Item 2  Item 3
# 1    32-7281683         Bel        Thursday       0       3       5
# 4    02-7819637         Ola        Thursday       0       0       2
# 5    99-1711438       Angie        Thursday       1       2       2
# 20   93-3149572  Cirstoforo        Thursday       5       5       2
# 21   93-3935642   Cleavland        Thursday       0       1       5
# 23   27-9961456       Korry        Thursday       3       1       4
# 27   26-4223212       Karen        Thursday       1       1       2
# 36   63-1272197       Normy        Thursday       1       5       0
# 41   20-5384747       Pyotr        Thursday       4       3       4
# 44   10-4533992        Ring        Thursday       1       0       0
# 50   14-3260544      Darrel        Thursday       5       2       4
# 57   64-7095228     Wendell        Thursday       1       0       4
# 60   62-2319142       Monty        Thursday       3       1       1
# ...

# %%
#Question 02b)
df.sort_values('Name',ascending=False)
# Out:
#     Purchase ID     Name Day of purchase  Item 1  Item 2  Item 3
# 54   45-3373993   Zollie          Monday       1       2       4
# 69   20-3226986   Wilton          Friday       2       2       2
# 90   01-3731251    Willy          Monday       5       4       1
# 10   75-7765891   Wileen        Saturday       2       3       1
# 57   64-7095228  Wendell        Thursday       1       0       4
# ..          ...      ...             ...     ...     ...     ...
# 34   11-2912056  Alaster          Friday       2       2       1
# 42   16-7402278   Alaric          Monday       1       4       0
# 109  59-6929730    Alano          Monday       2       5       5
# 53   51-0278805  Adolphe         Tuesday       2       3       4
# 31   09-5664863   Adolph         Tuesday       4       1       1
#
# [124 rows x 6 columns]

# %%
#Question 02c)
df.sort_values(['Name','Item 1'],ascending=True).head(10)
# Out:
#     Purchase ID     Name Day of purchase  Item 1  Item 2  Item 3
# 31   09-5664863   Adolph         Tuesday       4       1       1
# 53   51-0278805  Adolphe         Tuesday       2       3       4
# 109  59-6929730    Alano          Monday       2       5       5
# 42   16-7402278   Alaric          Monday       1       4       0
# 34   11-2912056  Alaster          Friday       2       2       1
# 8    29-1397295  Aloisia         Tuesday       2       4       0
# 5    99-1711438    Angie        Thursday       1       2       2
# 33   76-3802789   Bailie          Sunday       3       0       1
# 65   43-0561761      Bax        Saturday       1       2       2
# 1    32-7281683      Bel        Thursday       0       3       5

# %%
#Question 02d)
df= df.drop(columns=['Purchase ID'])
df
# Out:
#          Name Day of purchase  Item 1  Item 2  Item 3
# 0       Jenan        Saturday       4       4       3
# 1         Bel        Thursday       0       3       5
# 2    Jannelle          Sunday       0       2       4
# 3     Jo-anne        Saturday       0       3       2
# 4         Ola        Thursday       0       0       2
# ..        ...             ...     ...     ...     ...
# 119    Rockey          Friday       2       2       5
# 120  Johannah        Saturday       2       4       2
# 121   Bronson       Wednesday       3       3       3
# 122    Farlie        Thursday       2       4       2
# 123    Julina       Wednesday       0       3       0
#
# [124 rows x 5 columns]

# %%
#Question 02e)

df['Total Item'] = df['Item 1']+df['Item 2']+df['Item 3']
df
# Out:
#          Name Day of purchase  Item 1  Item 2  Item 3  Total Item
# 0       Jenan        Saturday       4       4       3          11
# 1         Bel        Thursday       0       3       5           8
# 2    Jannelle          Sunday       0       2       4           6
# 3     Jo-anne        Saturday       0       3       2           5
# 4         Ola        Thursday       0       0       2           2
# ..        ...             ...     ...     ...     ...         ...
# 119    Rockey          Friday       2       2       5           9
# 120  Johannah        Saturday       2       4       2           8
# 121   Bronson       Wednesday       3       3       3           9
# 122    Farlie        Thursday       2       4       2           8
# 123    Julina       Wednesday       0       3       0           3
#
# [124 rows x 6 columns]

# %%
#Question 02f)
df.columns

df=df[['Name', 'Day of purchase', 'Total Item', 'Item 1', 'Item 2', 'Item 3']]
df
# Out:
#          Name Day of purchase  Total Item  Item 1  Item 2  Item 3
# 0       Jenan        Saturday          11       4       4       3
# 1         Bel        Thursday           8       0       3       5
# 2    Jannelle          Sunday           6       0       2       4
# 3     Jo-anne        Saturday           5       0       3       2
# 4         Ola        Thursday           2       0       0       2
# ..        ...             ...         ...     ...     ...     ...
# 119    Rockey          Friday           9       2       2       5
# 120  Johannah        Saturday           8       2       4       2
# 121   Bronson       Wednesday           9       3       3       3
# 122    Farlie        Thursday           8       2       4       2
# 123    Julina       Wednesday           3       0       3       0
#
# [124 rows x 6 columns]

# %% [markdown]
# Question 3

# %%
#Question 3a)
import pandas as pd

df = pd.read_csv('PT01_02.csv')
df.duplicated().sum()
# Out:
# 3

# %%
#Question 3)
df.duplicated(subset=['Price']).sum()
# Out:
# 6

# %%
#Question 3c)
df.loc[df.duplicated(keep=False)]
# Out:
#    Purchase ID     Price      Day Gender
# 3   76-6713648  $206.31    Sunday   Male
# 4   76-6713648  $206.31    Sunday   Male
# 9   02-7819637  $233.75   Tuesday   Male
# 11  31-3981821  $215.62    Monday   Male
# 16  02-7819637  $233.75   Tuesday   Male
# 19  31-3981821  $215.62    Monday   Male

# %%
#Question 3d)
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
#Question 3e)
df.loc[df['Purchase ID'].str.contains('81',regex=True)].reset_index()
# Out:
#    index Purchase ID     Price      Day Gender
# 0      1  32-7281683       NaN   Monday   Male
# 1      5  02-7819637       NaN  Tuesday   Male
# 2      9  02-7819637  $233.75   Tuesday   Male
# 3     11  31-3981821  $215.62    Monday   Male

# %%
#Question 3f)
x = df['Day'].mode()
df['Day'].fillna(x[0], inplace = True)
df.head(10)
# Out:
#    Purchase ID     Price        Day  Gender
# 0   32-9842871  $261.94    Thursday    Male
# 1   32-7281683       NaN     Monday    Male
# 2   18-5587912   $32.76      Monday    Male
# 3   76-6713648  $206.31      Sunday    Male
# 5   02-7819637       NaN    Tuesday    Male
# 6   99-1711438  $300.12    Thursday    Male
# 7   62-3103838       NaN   Saturday  Female
# 8   08-9452186   $50.71   Wednesday  Female
# 9   02-7819637  $233.75     Tuesday    Male
# 10  29-1397295  $349.32    Thursday  Female
